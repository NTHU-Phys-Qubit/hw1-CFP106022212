# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2D Random walk
#
# We will concider three kinds of 2D random talk.
# * $dx$ and $dy$ are uniformly distributed between $[-1/2, +1/2]$.
# * $dx=+1$ with probability 1/2 and $dx=-1$ with probability 1/2. Similarly for $dy$.
# * $(dx, dy)=(\cos(\theta), \sin(\theta))$ where $\theta$ is uniformly distributed between $[0, 2\pi]$.
#
# For all kinds of the 2D random walk, you should do the following:
# * Plot a single trajectory.
# * Plot the distribution of the end point for an ensemble of trajectories.
# * Plot the histogram of the $r=x^2_f+y^2_f$ for an ensemble of trajectories.

# %%
a = np.zeros(2)
b = np.zeros((1000,2))
for i in range(1,1000):
    a += np.array([np.random.random()-0.5,np.random.random()-0.5])
    b[i] = a
plt.plot(b[:,0],b[:,1])

# %%
a = np.zeros(2)
b = np.zeros((1000,2))
for j in range(1000):
    a *= 0
    for i in range(1,100):
        a += np.array([np.random.random()-0.5,np.random.random()-0.5])
    b[j] = a
plt.scatter(b[:,0],b[:,1])

# %%
r = np.linalg.norm(b,axis=1)
plt.hist(r,bins = 20)
# Out:
# (array([ 24.,  51.,  79.,  93., 128., 123., 131.,  89.,  76.,  72.,  44.,
#          40.,  22.,   8.,   9.,   5.,   2.,   1.,   1.,   2.]),
#  array([ 0.08866335,  0.64745842,  1.2062535 ,  1.76504857,  2.32384364,
#          2.88263871,  3.44143378,  4.00022885,  4.55902393,  5.117819  ,
#          5.67661407,  6.23540914,  6.79420421,  7.35299929,  7.91179436,
#          8.47058943,  9.0293845 ,  9.58817957, 10.14697464, 10.70576972,
#         11.26456479]),
#  <a list of 20 Patch objects>)

# %%
a = np.zeros(2)
b = np.zeros((1000,2))
for i in range(1,1000):
    a += np.array([np.random.randint(2)*2-1,np.random.randint(2)*2-1])
    b[i] = a
plt.plot(b[:,0],b[:,1])

# %%
a = np.zeros(2)
b = np.zeros((1000,2))
for j in range(1000):
    a *= 0
    for i in range(1,100):
        a += np.array([np.random.randint(2)*2-1,np.random.randint(2)*2-1])
    b[j] = a
plt.scatter(b[:,0],b[:,1])

# %%
r = np.linalg.norm(b,axis=1)
plt.hist(r,bins = 20)
# Out:
# (array([ 73.,  28.,  86., 123., 115.,  93.,  94., 108.,  62.,  56.,  59.,
#          40.,  24.,  14.,   5.,  10.,   3.,   2.,   4.,   1.]),
#  array([ 1.41421356,  3.21566741,  5.01712125,  6.8185751 ,  8.62002894,
#         10.42148279, 12.22293663, 14.02439047, 15.82584432, 17.62729816,
#         19.42875201, 21.23020585, 23.0316597 , 24.83311354, 26.63456739,
#         28.43602123, 30.23747508, 32.03892892, 33.84038276, 35.64183661,
#         37.44329045]),
#  <a list of 20 Patch objects>)

# %%
a = np.zeros(2)
b = np.zeros((1000,2))
for i in range(1,1000):
    theta = np.random.random()*2*np.pi
    a += np.array([np.cos(theta),np.sin(theta)])
    b[i] = a
plt.plot(b[:,0],b[:,1])

# %%
a = np.zeros(2)
b = np.zeros((1000,2))
for j in range(1000):
    a *= 0
    for i in range(1,100):
        theta = np.random.random()*2*np.pi
        a += np.array([np.cos(theta),np.sin(theta)])
    b[j] = a
plt.scatter(b[:,0],b[:,1])

# %%
r = np.linalg.norm(b,axis=1)
plt.hist(r,bins = 20)
# Out:
# (array([ 26.,  68.,  95., 131., 133., 100.,  99.,  90.,  72.,  60.,  42.,
#          24.,  19.,  17.,   9.,   6.,   2.,   4.,   1.,   2.]),
#  array([ 0.21929714,  1.65410459,  3.08891205,  4.52371951,  5.95852696,
#          7.39333442,  8.82814187, 10.26294933, 11.69775678, 13.13256424,
#         14.5673717 , 16.00217915, 17.43698661, 18.87179406, 20.30660152,
#         21.74140897, 23.17621643, 24.61102389, 26.04583134, 27.4806388 ,
#         28.91544625]),
#  <a list of 20 Patch objects>)
